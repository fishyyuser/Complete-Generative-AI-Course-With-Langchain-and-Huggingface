# %% [markdown]
# #### RecurrsiveCharacterSplitter

# %%
# pdf loader
from langchain_community.document_loaders import PyPDFLoader

file_path = "pdf wiki.pdf"
loader = PyPDFLoader(file_path)

# %%
docs = loader.load()
docs
# Out:
# [Document(metadata={'producer': 'Skia/PDF m145', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36', 'creationdate': '2026-03-11T19:15:15+00:00', 'title': 'PDF - Wikipedia', 'moddate': '2026-03-11T19:15:15+00:00', 'source': 'pdf wiki.pdf', 'total_pages': 15, 'page': 0, 'page_label': '1'}, page_content='Portable Document Format\nAdobe PDF icon\nFilename\nextension\n.pdf\nInternet\nmedia type application/pdf,[1]\napplication/x-pdf\napplication/x-bzpdf\napplication/x-gzpdf\nType code PDF [1] (including a single\ntrailing space)\nUniform Type\nIdentifier (UTI)\ncom.adobe.pdf\nMagic number %PDF\nDeveloped by Adobe Inc. (1991–2008)\nISO (2008–)\nInitial release June 15, 1993\nLatest release 2.0\nExtended to PDF/A, PDF/E, PDF/UA,\nPDF/VT, PDF/X\nStandard ISO 32000-2\nOpen format? Yes\nWebsite iso.org/standard/75839\n.html (https://iso.org/standa\nrd/75839.html)\nPDF\nPortable Document Format (PDF),\nstandardized as IS
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)

# %%
final_docs=text_splitter.split_documents(docs)
final_docs
# Out:
# [Document(metadata={'producer': 'Skia/PDF m145', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36', 'creationdate': '2026-03-11T19:15:15+00:00', 'title': 'PDF - Wikipedia', 'moddate': '2026-03-11T19:15:15+00:00', 'source': 'pdf wiki.pdf', 'total_pages': 15, 'page': 0, 'page_label': '1'}, page_content='Portable Document Format\nAdobe PDF icon\nFilename\nextension\n.pdf\nInternet\nmedia type application/pdf,[1]\napplication/x-pdf\napplication/x-bzpdf\napplication/x-gzpdf\nType code PDF [1] (including a single\ntrailing space)\nUniform Type\nIdentifier (UTI)\ncom.adobe.pdf\nMagic number %PDF\nDeveloped by Adobe Inc. (1991–2008)\nISO (2008–)\nInitial release June 15, 1993\nLatest release 2.0\nExtended to PDF/A, PDF/E, PDF/UA,\nPDF/VT, PDF/X\nStandard ISO 32000-2\nOpen format? Yes\nWebsite iso.org/standard/75839'),
# ...

# %%
print(final_docs[0])
# Out:
# page_content='Portable Document Format
# Adobe PDF icon
# Filename
# extension
# .pdf
# Internet
# media type application/pdf,[1]
# application/x-pdf
# application/x-bzpdf
# application/x-gzpdf
# Type code PDF [1] (including a single
# trailing space)
# Uniform Type
# Identifier (UTI)
# com.adobe.pdf
# Magic number %PDF
# Developed by Adobe Inc. (1991–2008)
# ISO (2008–)
# Initial release June 15, 1993
# Latest release 2.0
# Extended to PDF/A, PDF/E, PDF/UA,
# PDF/VT, PDF/X
# Standard ISO 32000-2
# Open format? Yes
# Website iso.org/standard/75839' metadata={'producer': 'Skia/PDF m145', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36', 'creationdate': '2026-03-11T19:15:15+00:00', 'title': 'PDF - Wikipedia', 'moddate': '2026-03-11T19:15:15+00:00', 'source': 'pdf wiki.pdf', 'total_pages': 15, 'page': 0, 'page_label': '1'}

# %%
print(final_docs[1])
# Out:
# page_content='Open format? Yes
# Website iso.org/standard/75839
# .html (https://iso.org/standa
# rd/75839.html)
# PDF
# Portable Document Format (PDF),
# standardized as ISO 32000, is a file format
# developed by Adobe in 1993 used to present
# documents, including text formatting and images, in
# a manner independent of application software,
# hardware, and operating systems.[2][3] Based on the
# PostScript language, each PDF file encapsulates a
# complete description of a fixed-layout document,' metadata={'producer': 'Skia/PDF m145', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36', 'creationdate': '2026-03-11T19:15:15+00:00', 'title': 'PDF - Wikipedia', 'moddate': '2026-03-11T19:15:15+00:00', 'source': 'pdf wiki.pdf', 'total_pages': 15, 'page': 0, 'page_label': '1'}

# %%
speech=""
with open("speech.txt") as f:
    speech=f.read()
speech
# Out:
# 'Good evening everyone,\n\nSometimes we spend so much time looking for a topic, a direction, or a perfect idea that we forget something simple: thinking itself is interesting. Human beings have this strange habit of turning ordinary moments into something meaningful. A person walking down the street might be thinking about what to eat for dinner, while another person might be thinking about how to build a company, write a book, or change their life. The difference between those two people is not intelligence, luck, or even opportunity. Often, it is simply curiosity.\n\nCuriosity is one of the most powerful forces we have. It makes a child take apart a toy just to see how it works. It makes scientists spend years trying to answer questions that might seem useless to everyone else. It even drives ordinary people to try new things, learn new skills, and explore ideas they never considered before.\n\nBut curiosity alone is not enough. Curiosity without action becomes endless thinking. Yo
# ...

# %%
text_splitter=RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=15)
speech_docs=text_splitter.create_documents([speech])
speech_docs[0]
# Out:
# Document(metadata={}, page_content='Good evening everyone,')

# %%
speech_docs[1]
# Out:
# Document(metadata={}, page_content='Sometimes we spend so much time looking for a topic, a direction, or a perfect idea that we forget')

# %%
speech_docs[2]
# Out:
# Document(metadata={}, page_content='that we forget something simple: thinking itself is interesting. Human beings have this strange')

# %% [markdown]
# ### CharacterTextSplitter

# %%
from langchain_community.document_loaders import TextLoader
speech=TextLoader('speech.txt').load()

# %%
from langchain_text_splitters import CharacterTextSplitter
char_text_splitter=CharacterTextSplitter(separator="\n\n",chunk_size=100,chunk_overlap=20)
speech_dox=char_text_splitter.split_documents(speech)
# Out:
# Created a chunk of size 545, which is longer than the specified 100
# Created a chunk of size 330, which is longer than the specified 100
# Created a chunk of size 308, which is longer than the specified 100
# Created a chunk of size 332, which is longer than the specified 100
# Created a chunk of size 189, which is longer than the specified 100

# %%
speech_dox
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Good evening everyone,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Sometimes we spend so much time looking for a topic, a direction, or a perfect idea that we forget something simple: thinking itself is interesting. Human beings have this strange habit of turning ordinary moments into something meaningful. A person walking down the street might be thinking about what to eat for dinner, while another person might be thinking about how to build a company, write a book, or change their life. The difference between those two people is not intelligence, luck, or even opportunity. Often, it is simply curiosity.'),
# ...

# %% [markdown]
# ### HTML Text Splitter

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
html_string="""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>LangChain HTML Text Splitter Test Page</title>
</head>

<body>

<h1>Artificial Intelligence Overview</h1>
<p>
Artificial Intelligence (AI) refers to the simulation of human intelligence in machines.
These systems are designed to perform tasks such as reasoning, learning, perception,
and decision making.
</p>

<h2>History of Artificial Intelligence</h2>
<p>
The field of AI began in the 1950s with early work in symbolic reasoning and rule-based systems.
Researchers believed machines could eventually mimic human cognition.
</p>

<h3>Early AI Research</h3>
<p>
Early AI systems focused on logical reasoning and symbolic problem solving.
Programs such as the Logic Theorist and General Problem Solver were developed
to mimic human reasoning processes.
</p>

<h3>AI Winters</h3>
<p>
Periods known as "AI winters" occurred when expectations exceeded technological
capabilities, causing funding and interest in AI research to decline.
</p>

<h2>Machine Learning</h2>
<p>
Machine learning is a subset of AI focused on enabling machines to learn from data.
Instead of explicitly programming rules, models discover patterns automatically.
</p>

<h3>Supervised Learning</h3>
<p>
Supervised learning involves training models on labeled datasets.
Examples include classification and regression problems.
</p>

<h3>Unsupervised Learning</h3>
<p>
Unsupervised learning identifies patterns in unlabeled data.
Common methods include clustering and dimensionality reduction.
</p>

<h2>Applications of AI</h2>
<p>
AI has applications across many industries including healthcare,
finance, transportation, and entertainment.
</p>

<h3>Healthcare</h3>
<p>
AI assists doctors with diagnostics, medical imaging analysis,
and predictive healthcare systems.
</p>

<h3>Finance</h3>
<p>
In finance, AI is used for fraud detection, algorithmic trading,
risk analysis, and customer support automation.
</p>

<h2>Example List</h2>

<h3>Popular AI Frameworks</h3>
<ul>
    <li>TensorFlow</li>
    <li>PyTorch</li>
    <li>Scikit-learn</li>
    <li>Keras</li>
</ul>

<h3>Typical AI Workflow</h3>
<ol>
    <li>Collect Data</li>
    <li>Clean and Preprocess Data</li>
    <li>Train Model</li>
    <li>Evaluate Model</li>
    <li>Deploy Model</li>
</ol>

<h2>Example Table</h2>

<table border="1">
<tr>
    <th>Model</th>
    <th>Type</th>
    <th>Use Case</th>
</tr>
<tr>
    <td>ResNet</td>
    <td>CNN</td>
    <td>Image Recognition</td>
</tr>
<tr>
    <td>BERT</td>
    <td>Transformer</td>
    <td>Natural Language Processing</td>
</tr>
<tr>
    <td>GPT</td>
    <td>Transformer</td>
    <td>Text Generation</td>
</tr>
</table>

<h2>Conclusion</h2>
<p>
Artificial Intelligence continues to evolve rapidly with advances
in deep learning, large language models, and multimodal systems.
Future developments may further integrate AI into everyday life.
</p>

</body>
</html>
"""

# %%
headers_to_split=[
    ("h1","Header 1"),
    ("h2","Header 2"),
    ("h3","Header 3")
]
html_splitter=HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split)

# %%
html_header_splits=html_splitter.split_text(html_string)
html_header_splits
# Out:
# [Document(metadata={'Header 1': 'Artificial Intelligence Overview'}, page_content='Artificial Intelligence Overview'),
#  Document(metadata={'Header 1': 'Artificial Intelligence Overview'}, page_content='Artificial Intelligence (AI) refers to the simulation of human intelligence in machines.\nThese systems are designed to perform tasks such as reasoning, learning, perception,\nand decision making.'),
#  Document(metadata={'Header 1': 'Artificial Intelligence Overview', 'Header 2': 'History of Artificial Intelligence'}, page_content='History of Artificial Intelligence'),
#  Document(metadata={'Header 1': 'Artificial Intelligence Overview', 'Header 2': 'History of Artificial Intelligence'}, page_content='The field of AI began in the 1950s with early work in symbolic reasoning and rule-based systems.\nResearchers believed machines could eventually mimic human cognition.'),
# ...

# %%
for doc in html_header_splits:
    print(doc.page_content)
    print("-----")
# Out:
# Artificial Intelligence Overview
# -----
# Artificial Intelligence (AI) refers to the simulation of human intelligence in machines.
# These systems are designed to perform tasks such as reasoning, learning, perception,
# and decision making.
# -----
# History of Artificial Intelligence
# -----
# The field of AI began in the 1950s with early work in symbolic reasoning and rule-based systems.
# Researchers believed machines could eventually mimic human cognition.
# -----
# Early AI Research
# -----
# Early AI systems focused on logical reasoning and symbolic problem solving.
# Programs such as the Logic Theorist and General Problem Solver were developed
# to mimic human reasoning processes.
# -----
# AI Winters
# -----
# Periods known as "AI winters" occurred when expectations exceeded technological
# capabilities, causing funding and interest in AI research to decline.
# -----
# Machine Learning
# -----
# ...

# %%
url = "https://www.w3schools.com/html/html_headings.asp"

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
    ("h4", "Header 4"),
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on)
html_header_splits = html_splitter.split_text_from_url(url)
html_header_splits
# Out:
# [Document(metadata={}, page_content='Google Tag Manager (noscript) End Google Tag Manager (noscript) <div class="topnav notranslate" id=\'topnav\' style="position:fixed!important;top:56px">\n  <div style="overflow:auto;">\n    <div class="w3-bar w3-left topnavbar" style="width:100%;overflow:hidden;height:32px">\n\n      <a href=\'javascript:void(0);\' class=\'topnav-icons fa fa-menu w3-hide-large w3-left w3-bar-item w3-button ga-nav\' style="line-height:1.1;padding-top:8px!important;padding-bottom:7px!important;" onclick=\'open_menu()\' title=\'Menu\'></a>\n\n      <a href=\'/default.asp\' style="display:none" class=\'topnav-icons fa fa-home w3-left w3-bar-item w3-button ga-nav\' title=\'Home\'></a>\n      <a class="w3-bar-item w3-button ga-nav" href=\'/html/default.asp\' title=\'HTML Tutorial\' style="padding-left:18px!important;padding-right:18px!important;">HTML</a>\n      <a class="w3-bar-item w3-button ga-nav" href=\'/css/default.asp\' title=\'CSS Tutorial\'>CSS</a>\n      <a cl
# ...

# %%
len(html_header_splits)
# Out:
# 151

# %%
print(html_header_splits[28].page_content)
# Out:
# JavaScript
# Exercise
# Quiz
# React
# Exercise
# Quiz
# jQuery
# Exercise
# Quiz
# Vue
# Exercise
# Quiz
# Angular
# Exercise
# Quiz
# <div
#                   data-name="aws cloud"
#                   data-category="backend"
#                 >
#                   <a
#
#                     class="w3-bar-item w3-button acctop-link ga-top-drop ga-top-drop-ex-aws-cloud"
#                     href="/aws/aws_exercises.php"
#                     title="AWS Cloud Exercises"
#                   >
#                     AWS Cloud
#                   </a>
#                   <a
#
#                     class="ws-btn acclink-text ga-top-drop ga-top-drop-ex-aws-cloud"
#                     href="/aws/aws_exercises.php"
#                     title="AWS Cloud Exercises"
#                   >
#                     Exercise
#                   </a>
#                   <a
#
#                     class="ws-btn acclink-text ga-top-drop ga-top-drop-qz-aws-cloud"
# ...

# %% [markdown]
# #### JSON Splitter

# %%
import json

import requests

# This is a large nested json object and will be loaded as a python dict
json_data = requests.get("https://api.smith.langchain.com/openapi.json").json()

# %%
json_data
# Out:
# {'openapi': '3.1.0',
#  'info': {'title': 'LangSmith',
#   'description': 'The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n',
#   'version': '0.1.0'},
#  'paths': {'/api/v1/audit-logs': {'get': {'tags': ['audit-logs'],
#     'summary': 'Get Audit Logs',
#     'description': "Retrieve audit log records for the authenticated user's organization in OCSF format.\n\nRequires both start_time and end_time parameters to filter logs within a date range.\nSupports cursor-based pagination.\n\nReturns results in OCSF API Activity (Class UID: 6003) format,\nwhich is compatible with security monitoring and SIEM tools.\nReference: https://schema.ocsf.io/1.7.0/classes/api_activity",
# ...

# %%
from langchain_text_splitters import RecursiveJsonSplitter

splitter = RecursiveJsonSplitter(max_chunk_size=300)

# %%
json_chunks=splitter.create_documents(texts=[json_data])
json_chunks
# Out:
# [Document(metadata={}, page_content='{"openapi": "3.1.0", "info": {"title": "LangSmith", "description": "The LangSmith API is used to programmatically create and manage LangSmith resources.\\n\\n## Host\\nhttps://api.smith.langchain.com\\n\\n## Authentication\\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\\n\\n"}}'),
#  Document(metadata={}, page_content='{"info": {"version": "0.1.0"}, "paths": {"/api/v1/audit-logs": {"get": {"tags": ["audit-logs"], "summary": "Get Audit Logs"}}}}'),
# ...

# %%
for chunk in json_chunks[:3]:
    print(chunk.page_content)
# Out:
# {"openapi": "3.1.0", "info": {"title": "LangSmith", "description": "The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n"}}
# {"info": {"version": "0.1.0"}, "paths": {"/api/v1/audit-logs": {"get": {"tags": ["audit-logs"], "summary": "Get Audit Logs"}}}}
# {"paths": {"/api/v1/audit-logs": {"get": {"description": "Retrieve audit log records for the authenticated user's organization in OCSF format.\n\nRequires both start_time and end_time parameters to filter logs within a date range.\nSupports cursor-based pagination.\n\nReturns results in OCSF API Activity (Class UID: 6003) format,\nwhich is compatible with security monitoring and SIEM tools.\nReference: https://schema.ocsf.io/1.7.0/classes/api_activity"}}}}
