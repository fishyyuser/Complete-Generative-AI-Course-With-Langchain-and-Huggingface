# %% [markdown]
# ## OPEN AI Embeddings

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_key"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
embeddingsOpAI= OpenAIEmbeddings(model="text-embedding-3-small")
embeddingsOpAI
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x000002A028DF71C0>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x000002A028DF7220>, model='text-embedding-3-small', dimensions=None, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
text="I am learning GenAI with Langchain and Hugginface and currently i am learning embeddings. I am using open ai embeddings"

# %%
vec=embeddingsOpAI.embed_query(text)

# %%
len(vec)
# Out:
# 1536

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=20)

# %%
speech=""
with open("speech2.txt") as f:
    speech=f.read()
speech
# Out:
# "Imagine standing at the edge of a forest just before sunrise. The world is quiet, almost as if nature itself is holding its breath before the day begins. The air is cool, the ground still damp with morning dew, and the sky slowly shifts from deep blue to shades of orange and gold. In that quiet moment, before the noise of the day begins, you can hear things that are usually drowned out: the rustle of leaves, the distant call of birds, and the subtle rhythm of the wind moving through trees. These moments remind us of something important: progress and movement do not always require noise. Sometimes the most meaningful change begins quietly.\n\nIn our modern world, we often associate progress with speed, scale, and visibility. We celebrate big announcements, rapid growth, and dramatic breakthroughs. But if you look closely at the way real transformation happens—whether in science, technology, education, or personal growth—you will notice that it often begins slowly and almost invisibly
# ...

# %%
docs=text_splitter.create_documents([speech])
len(docs)
# Out:
# 26

# %%
docs
# Out:
# [Document(metadata={}, page_content='Imagine standing at the edge of a forest just before sunrise. The world is quiet, almost as if nature itself is holding its breath before the day begins. The air is cool, the ground still damp with'),
#  Document(metadata={}, page_content='still damp with morning dew, and the sky slowly shifts from deep blue to shades of orange and gold. In that quiet moment, before the noise of the day begins, you can hear things that are usually'),
#  Document(metadata={}, page_content='that are usually drowned out: the rustle of leaves, the distant call of birds, and the subtle rhythm of the wind moving through trees. These moments remind us of something important: progress and'),
#  Document(metadata={}, page_content='progress and movement do not always require noise. Sometimes the most meaningful change begins quietly.'),
# ...

# %%
#vector embedding and vector storeDB
from langchain_community.vectorstores import Chroma
db=Chroma.from_documents(docs,embeddingsOpAI)
db

# %%
query="What is the importance of curiosity?"
query_ans=db.similarity_search(query,k=2)
query_ans
# Out:
# [Document(metadata={}, page_content='Another important aspect of progress is curiosity. Curiosity drives people to explore unfamiliar ideas, question assumptions, and search for better solutions. It encourages experimentation and'),
#  Document(metadata={}, page_content='Curiosity is one of the most powerful forces we have. It makes a child take apart a toy just to see how it works. It makes scientists spend years trying to answer questions that might seem useless to')]

# %% [markdown]
# ### Ollama Embeddings

# %%
from langchain_community.embeddings import OllamaEmbeddings
embeddings=OllamaEmbeddings(model="embeddinggemma")
texts=["Alpha is the first letter of the greek letter","Omega is the last character of the greek letter"]
# Out:
# C:\Users\prady\AppData\Local\Temp\ipykernel_16188\3155258681.py:2: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embeddings=OllamaEmbeddings(model="embeddinggemma")

# %%
r1=embeddings.embed_documents(texts)
r1
# Out:
# [[-0.08962474763393402,
#   0.04310156777501106,
#   -0.030093293637037277,
#   -0.023310892283916473,
#   -0.04194023460149765,
#   0.015371718443930149,
#   0.003013400360941887,
#   -0.0019488208927214146,
#   0.03269829973578453,
#   0.012925500981509686,
#   -0.010228956118226051,
#   -0.06589210033416748,
#   -0.0027111603412777185,
#   -0.03904232010245323,
#   0.034116894006729126,
#   0.05569194257259369,
#   0.0192535649985075,
#   -0.044627074152231216,
#   -0.03202510252594948,
#   -0.0014353729784488678,
#   0.0365527868270874,
#   -0.06504599750041962,
#   -0.045892514288425446,
#   -0.010861458256840706,
#   0.00531602930277586,
#   0.014400833286345005,
#   -0.0007641459815204144,
#   -0.015718713402748108,
#   -0.0366002656519413,
#   0.006151521112769842,
#   0.029557395726442337,
#   0.005526179447770119,
#   0.06737934798002243,
#   0.03700648248195648,
#   0.02883884869515896,
#   0.05798635259270668,
#   -0.024759622290730476,
#   0.021359380334615707,
# ...

# %%
response=embeddings.embed_query("What is the first letter of greek alphabet")

# %%
print(response)
print(r1[0])
# Out:
# [-0.11571244895458221, 0.0026504071429371834, -0.041509680449962616, -0.01716710813343525, 0.01645062305033207, 0.0032819260377436876, 0.0013872843701392412, -0.037997666746377945, 0.024559512734413147, 0.03788718581199646, -0.02015775628387928, -0.022296076640486717, 0.0019298780243843794, -0.0428728424012661, 0.06517395377159119, 0.039210569113492966, -0.013463632203638554, -0.12868355214595795, 0.004462024196982384, 0.01673755794763565, 0.0347745306789875, -0.014896626584231853, -0.037853263318538666, -0.00016968444106169045, 0.00551276421174407, 0.02355891466140747, -0.023266326636075974, -0.002887183101847768, -0.036959290504455566, 0.0419110432267189, 0.027166591957211494, 0.012404612265527248, 0.024685444310307503, 0.01944120042026043, 0.00026813402655534446, 0.07001502066850662, -0.012936607003211975, 0.012997021898627281, -0.06629674881696701, -0.019049599766731262, -0.09525462239980698, 0.061801232397556305, -0.013853470794856548, -0.011008841916918755, -0.02031370997428894
# ...

# %% [markdown]
# #### Hugginface Embeddings

# %%
os.environ["HF_API_KEY"]=os.getenv("HF_API_KEY")
